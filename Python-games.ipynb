# %%
print("I, Shubham Mankar, a first-year Computer Engineering student at MIT Academy of Engineering,\n"
      "am starting my Python game development journey with excitement and curiosity.\n"
      "I aim to learn, create, and improve my coding skills by building games.")

# 1. Rock Paper Scissor
# Out:
# I, Shubham Mankar, a first-year Computer Engineering student at MIT Academy of Engineering,
# am starting my Python game development journey with excitement and curiosity.
# I aim to learn, create, and improve my coding skills by building games.

# %%
print("------------ Rock Paper Scissor -------------")
# Out:
# ------------ Rock Paper Scissor -------------

# %%
print("------------ Rock Paper Scissor -------------")
print("\033[1m Select Your Choices From Below : ") # BOLD TEXt CLOSE BY 
print(" 1. Rock\n 2. Paper\n 3. Scissor")
import random

choices = ["Rock","Paper","Scissor"]

user = input("Enter Your choice")
comp = random.choice(choices)

print(f"you Chossed {user} And Comp Choosed {comp}")
if user == comp:
    print("Match Draw !!")

elif user == "Rock":
    if comp == "Paper":
        print("You lost!")
    else:
        print("You Won!!")

elif user == "Paper":
    if comp == "Scissor":
        print("You Lost!")
    else:
        print("you Won!!")

elif user == "Scissor":
    if comp == "Rock":
        print("You lost!!")
    else:
        print("You Won")
# Out:
# ------------ Rock Paper Scissor -------------
#  Select Your Choices From Below :
#  1. Rock
#  2. Paper
#  3. Scissor
# you Chossed Rock And Comp Choosed Paper
# You lost!

# %%
print("------------ DICE ROLLER -------------")
import random 

while True:
    input("Press Enter To Roll The Dice")

    dice = random.randint(1,6)
    print(f"YOU ROLLED {dice}")
    exitt = input("To exit Type Exit : ").lower()
    if exitt == "exit":
        print("Thanks for playing..")
        break
# Out:
# ------------ DICE ROLLER -------------
# YOU ROLLED 6
# YOU ROLLED 3
# YOU ROLLED 4
# YOU ROLLED 4
# YOU ROLLED 2
# Thanks for playing..

# %%
import random 
print("------------ Computer QUIZ! -------------")

questions = [
    ("What keyword is used to print in Python?", "print"),
    ("Which symbol is used for comments in Python?", "#"),
    ("What data type is 10?", "int"),
    ("What data type is 3.14?", "float"),
    ("What function is used to take input from user?", "input"),
    ("What keyword is used to create a loop that runs while condition is true?", "while"),
    ("Which keyword is used for decision making?", "if"),
    ("What keyword stops a loop?", "break"),
    ("What keyword skips one loop iteration?", "continue"),
    ("What keyword is used to define a function?", "def")
]
play = input("Do you want to play? ")
while questions:

    i = random.choice(questions)
    ans = input(i[0]).lower()
    questions.remove(i)

    if ans == "exit":
        break

    if ans == i[1]:
        print("correct!\n")
    else:
        print("Wrong! Answer!! \ncorrect Answer is : ", i[1], "\n")

print("Quiz finished!!")
print("Thanks For Playing...")
# Out:
# ------------ Computer QUIZ! -------------
# Wrong! Answer!!
#  correct Answer is :  float
